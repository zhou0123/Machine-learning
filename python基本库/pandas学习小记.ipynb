# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])

# %%
df.shape
# Out:
# (6, 6)

# %%
df
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df.info
# Out:
# <bound method DataFrame.info of      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0>

# %%
df.age
# Out:
# 0    23
# 1    44
# 2    54
# 3    32
# 4    34
# 5    32
# Name: age, dtype: int64

# %%
df.id.name
# Out:
# 'id'

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df.isnull()
# Out:
#       id   date   city  category    age  price
# 0  False  False  False     False  False  False
# 1  False  False  False     False  False   True
# 2  False  False  False     False  False  False
# 3  False  False  False     False  False  False
# 4  False  False  False     False  False   True
# 5  False  False  False     False  False  False

# %%
df.values
# Out:
# array([[1001, Timestamp('2013-01-02 00:00:00'), 'Beijing ', '100-A', 23,
#         1200.0],
#        [1002, Timestamp('2013-01-03 00:00:00'), 'SH', '100-B', 44, nan],
#        [1003, Timestamp('2013-01-04 00:00:00'), ' guangzhou ', '110-A',
#         54, 2133.0],
#        [1004, Timestamp('2013-01-05 00:00:00'), 'Shenzhen', '110-C', 32,
#         5433.0],
#        [1005, Timestamp('2013-01-06 00:00:00'), 'shanghai', '210-A', 34,
#         nan],
#        [1006, Timestamp('2013-01-07 00:00:00'), 'BEIJING ', '130-F', 32,
#         4432.0]], dtype=object)

# %%
df.head() #默认前5行数据
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN

# %%
df.tail()    #默认后5行数据
# Out:
#      id       date         city category  age   price
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %% [markdown]
# # 1、用数字0填充空值：

# %%
df.fillna(value=0)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %% [markdown]
# # 2、使用列price的均值对NA进行填充：

# %%
df
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['price']=df['price']=df['price'].fillna(df['price'].mean())

# %% [markdown]
# # 3、清楚city字段的字符空格：

# %%
df['city'].map(str.strip)
# Out:
# 0      Beijing
# 1           SH
# 2    guangzhou
# 3     Shenzhen
# 4     shanghai
# 5      BEIJING
# Name: city, dtype: object

# %% [markdown]
# # 4、大小写转换：

# %%
df['city'].str.lower()
# Out:
# 0       beijing
# 1             sh
# 2     guangzhou
# 3       shenzhen
# 4       shanghai
# 5       beijing
# Name: city, dtype: object

# %% [markdown]
# # 5、更改数据格式：

# %%
df['price'].astype('int')
# Out:
# 0    1200
# 1    3299
# 2    2133
# 3    5433
# 4    3299
# 5    4432
# Name: price, dtype: int32

# %% [markdown]
# # 6、更改列名称：

# %%
df.rename(columns={'category':'cate'})
# Out:
#      id       date         city   cate  age   price
# 0  1001 2013-01-02     Beijing   100-A   23  1200.0
# 1  1002 2013-01-03           SH  100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou   110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen  110-C   32  5433.0
# 4  1005 2013-01-06     shanghai  210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING   130-F   32  4432.0

# %% [markdown]
# # 7、删除后出现的重复值：

# %%
df['city'].drop_duplicates()
# Out:
# 0       Beijing
# 1             SH
# 2     guangzhou
# 3       Shenzhen
# 4       shanghai
# 5       BEIJING
# Name: city, dtype: object

# %% [markdown]
# # 8 、删除先出现的重复值：

# %%
df['city'].drop_duplicates(keep='last')
# Out:
# 0       Beijing
# 1             SH
# 2     guangzhou
# 3       Shenzhen
# 4       shanghai
# 5       BEIJING
# Name: city, dtype: object

# %% [markdown]
# # 9、数据替换：

# %%
df['city'].replace('SH','shanghai')
# Out:
# 0       Beijing
# 1       shanghai
# 2     guangzhou
# 3       Shenzhen
# 4       shanghai
# 5       BEIJING
# Name: city, dtype: object

# %% [markdown]
# # 四、数据预处理

# %%
df1=pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006,1007,1008], 
"gender":['male','female','male','female','male','female','male','female'],
"pay":['Y','N','Y','Y','N','Y','N','Y',],
"m-point":[10,12,20,40,40,40,30,20]})

# %%
df
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df1
# Out:
#      id  gender pay  m-point
# 0  1001    male   Y       10
# 1  1002  female   N       12
# 2  1003    male   Y       20
# 3  1004  female   Y       40
# 4  1005    male   N       40
# 5  1006  female   Y       40
# 6  1007    male   N       30
# 7  1008  female   Y       20

# %% [markdown]
# # 1、数据表合并

# %% [markdown]
# # 1.1 merge

# %%
df1=df1.rename(columns={'id':'IDa'})

# %%
df1
# Out:
#     IDa  gender pay  m-point
# 0  1001    male   Y       10
# 1  1002  female   N       12
# 2  1003    male   Y       20
# 3  1004  female   Y       40
# 4  1005    male   N       40
# 5  1006  female   Y       40
# 6  1007    male   N       30
# 7  1008  female   Y       20

# %% [markdown]
# # 没有一致的col出错

# %%
df_inner=pd.merge(df,df1,how='inner')

# %%
df1=df1.rename(columns={'IDa':'id'})

# %%
df_inner
# Out:
#      id       date         city category  age   price  gender pay  m-point
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40

# %%
df_outer=pd.merge(df,df1,how='outer')

# %%
df_outer
# Out:
#      id       date         city category   age   price  gender pay  m-point
# 0  1001 2013-01-02     Beijing     100-A  23.0  1200.0    male   Y       10
# 1  1002 2013-01-03           SH    100-B  44.0  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A  54.0  2133.0    male   Y       20
# 3  1004 2013-01-05     Shenzhen    110-C  32.0  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A  34.0  3299.5    male   N       40
# 5  1006 2013-01-07     BEIJING     130-F  32.0  4432.0  female   Y       40
# 6  1007        NaT          NaN      NaN   NaN     NaN    male   N       30
# 7  1008        NaT          NaN      NaN   NaN     NaN  female   Y       20

# %%
df_left=pd.merge(df,df1,how='left')        #

# %%
df_left
# Out:
#      id       date         city category  age   price  gender pay  m-point
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40

# %% [markdown]
# # 1.2 append

# %%
result = df1.append(df)

# %%
result
# Out:
#      id  gender  pay  m-point       date         city category   age   price
# 0  1001    male    Y     10.0        NaT          NaN      NaN   NaN     NaN
# 1  1002  female    N     12.0        NaT          NaN      NaN   NaN     NaN
# 2  1003    male    Y     20.0        NaT          NaN      NaN   NaN     NaN
# 3  1004  female    Y     40.0        NaT          NaN      NaN   NaN     NaN
# 4  1005    male    N     40.0        NaT          NaN      NaN   NaN     NaN
# 5  1006  female    Y     40.0        NaT          NaN      NaN   NaN     NaN
# 6  1007    male    N     30.0        NaT          NaN      NaN   NaN     NaN
# 7  1008  female    Y     20.0        NaT          NaN      NaN   NaN     NaN
# 0  1001     NaN  NaN      NaN 2013-01-02     Beijing     100-A  23.0  1200.0
# 1  1002     NaN  NaN      NaN 2013-01-03           SH    100-B  44.0  3299.5
# 2  1003     NaN  NaN      NaN 2013-01-04   guangzhou     110-A  54.0  2133.0
# ...

# %% [markdown]
# # 1.3 join

# %% [markdown]
# # 2、设置索引列

# %%
df2=df.set_index('id')

# %%
df.shape
# Out:
# (6, 6)

# %%
df2.shape
# Out:
# (6, 5)

# %%
df.sort_values(by=['age'])
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0

# %% [markdown]
# # 4、按照索引列排序：

# %%
df2.sort_index()
# Out:
#            date         city category  age   price
# id
# 1001 2013-01-02     Beijing     100-A   23  1200.0
# 1002 2013-01-03           SH    100-B   44  3299.5
# 1003 2013-01-04   guangzhou     110-A   54  2133.0
# 1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 1005 2013-01-06     shanghai    210-A   34  3299.5
# 1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df_inner['group']=np.where(df['price']>3000,'high','low')

# %%
df_inner
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40
#
#   group
# 0   low
# 1  high
# 2   low
# 3  high
# 4  high
# 5  high

# %%
df_inner.loc[((df_inner['price'] >= 1000)&(df_inner['age']>30)), 'si']='A'

# %%
df_inner
# Out:
#      id       date         city category  age   price  gender pay  m-point si
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10  E
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12  A
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20  A
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40  A
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40  A
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40  A

# %% [markdown]
# # 对category字段的值依次进行分列，并创建数据表，索引值为df_inner的索引列，列名称为category和size

# %%
df_inner
# Out:
#      id       date         city category  age   price  gender pay  m-point si
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10  E
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12  A
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20  A
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40  A
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40  A
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40  A

# %%
pd.DataFrame((x.split('-') for x in df_inner['category']),index=df.index,columns=['cate','size'])
# Out:
#   cate size
# 0  100    A
# 1  100    B
# 2  110    A
# 3  110    C
# 4  210    A
# 5  130    F

# %%
c=lambda x : x.split('-')

# %%
list(map(c,df_inner['category']))
# Out:
# [['100', 'A'],
#  ['100', 'B'],
#  ['110', 'A'],
#  ['110', 'C'],
#  ['210', 'A'],
#  ['130', 'F']]

# %%
pd.DataFrame(list(map(c,df_inner['category'])),index=[1,2,3,4,5,6],columns=['A','B'])
# Out:
#      A  B
# 1  100  A
# 2  100  B
# 3  110  A
# 4  110  C
# 5  210  A
# 6  130  F

# %%
[x.split('-') for x in df_inner['category']]
# Out:
# [['100', 'A'],
#  ['100', 'B'],
#  ['110', 'A'],
#  ['110', 'C'],
#  ['210', 'A'],
#  ['130', 'F']]

# %%
df_inner
# Out:
#      id       date         city category  age   price  gender pay  m-point
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           SH    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0  female   Y       40

# %%
df
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df_in=pd.merge(df_inner,df,right_index=True, left_index=True)

# %%
df_in
# Out:
#    id_x     date_x       city_x category_x  age_x  price_x  gender pay  \
# 0  1001 2013-01-02     Beijing       100-A     23   1200.0    male   Y
# 1  1002 2013-01-03           SH      100-B     44   3299.5  female   N
# 2  1003 2013-01-04   guangzhou       110-A     54   2133.0    male   Y
# 3  1004 2013-01-05     Shenzhen      110-C     32   5433.0  female   Y
# 4  1005 2013-01-06     shanghai      210-A     34   3299.5    male   N
# 5  1006 2013-01-07     BEIJING       130-F     32   4432.0  female   Y
#
#    m-point  id_y     date_y       city_y category_y  age_y  price_y
# 0       10  1001 2013-01-02     Beijing       100-A     23   1200.0
# 1       12  1002 2013-01-03           SH      100-B     44   3299.5
# 2       20  1003 2013-01-04   guangzhou       110-A     54   2133.0
# 3       40  1004 2013-01-05     Shenzhen      110-C     32   5433.0
# 4       40  1005 2013-01-06     shanghai      210-A     34   3299.5
# ...

# %% [markdown]
# # 五、数据提取

# %%
df_inner=df_inner.set_index('date')

# %%
df_inner
# Out:
#               id         city category  age   price  gender pay  m-point
# date
# 2013-01-02  1001     Beijing     100-A   23  1200.0    male   Y       10
# 2013-01-03  1002           SH    100-B   44  3299.5  female   N       12
# 2013-01-04  1003   guangzhou     110-A   54  2133.0    male   Y       20
# 2013-01-05  1004     Shenzhen    110-C   32  5433.0  female   Y       40
# 2013-01-06  1005     shanghai    210-A   34  3299.5    male   N       40
# 2013-01-07  1006     BEIJING     130-F   32  4432.0  female   Y       40

# %%
df_inner.loc[((df_inner['age'] > 2) & (df_inner['gender'] == 'male')), ['id','city','age','category','gender']]
# Out:
#      id         city  age category gender
# 0  1001     Beijing    23    100-A   male
# 2  1003   guangzhou    54    110-A   male
# 4  1005     shanghai   34    210-A   male

# %%
df_inner.groupby('gender').count()
# Out:
#         id  date  city  category  age  price  pay  m-point
# gender
# female   3     3     3         3    3      3    3        3
# male     3     3     3         3    3      3    3        3

# %%
df_inner.groupby('gender')['price'].agg([len,np.sum, np.mean])
# Out:
#         len      sum         mean
# gender
# female  3.0  13164.5  4388.166667
# male    3.0   6632.5  2210.833333

# %% [markdown]
# # 1、对所有的列进行计数汇总

# %%
df_inner.groupby('gender').count()
# Out:
#         id  date  city  category  age  price  pay  m-point
# gender
# female   3     3     3         3    3      3    3        3
# male     3     3     3         3    3      3    3        3

# %%
df_inner.groupby('gender')['id'].count()
# Out:
# gender
# female    3
# male      3
# Name: id, dtype: int64

# %%
df_inner.groupby(['city','gender'])['id'].count()
# Out:
# city         gender
#  guangzhou   male      1
# BEIJING      female    1
# Beijing      male      1
# SH           female    1
# Shenzhen     female    1
# shanghai     male      1
# Name: id, dtype: int64

# %% [markdown]
# # 八、数据统计

# %%
df_inner.sample(n=3)
# Out:
#      id       date      city category  age   price  gender pay  m-point
# 0  1001 2013-01-02  Beijing     100-A   23  1200.0    male   Y       10
# 4  1005 2013-01-06  shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07  BEIJING     130-F   32  4432.0  female   Y       40

# %% [markdown]
# # 2、手动设置采样权重

# %%
weights = [0, 0, 0, 0, 0.8, 0.2]
df_inner.sample(n=2, weights=weights)
# Out:
#      id       date      city category  age   price  gender pay  m-point
# 4  1005 2013-01-06  shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07  BEIJING     130-F   32  4432.0  female   Y       40

# %% [markdown]
# # 采样后放回

# %%
df_inner.sample(n=6, replace=True)
# Out:
#      id       date         city category  age   price gender pay  m-point
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0   male   Y       10
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5   male   N       40
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0   male   Y       10
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5   male   N       40
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0   male   Y       20
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0   male   Y       10

# %% [markdown]
# # 计算标准差

# %%
df_inner['price'].std()
# Out:
# 1523.3516337339847
