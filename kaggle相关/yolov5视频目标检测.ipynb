# %%
# %mkdir conv

# %%
# %cd conv
# Out:
# C:\Users\zhou\Documents\kaggle\conv

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
cd yolov5
# Out:
# C:\Users\zhou\Documents\kaggle\conv\yolov5

# %%
# !pip install -r requirements.txt

# %%
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\zhou/.netrc
# True

# %%
# !python train.py --data ../Taiga/Taiga.yaml --cfg ./models/yolov5s.yaml --epochs 200 --batch-size 2
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=../Taiga/Taiga.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
#
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.26, Best Possible Recall (BPR) = 1.0000
#                  all         53         66     0.0862     0.0303    0.00814      0.001
#                  all         53         66     0.0517     0.0152    0.00566   0.000961
# ...

# %%
# !python detect.py --weight ./runs/train/exp5/weights/best.pt --source cute.mp4
# Out:
# detect: weights=['./runs/train/exp5/weights/best.pt'], source=cute.mp4, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# video 1/1 (1/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.013s)
# video 1/1 (2/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.011s)
# video 1/1 (3/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.011s)
# video 1/1 (4/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.011s)
# video 1/1 (5/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.012s)
# video 1/1 (6/1096) C:\Users\zhou\Documents\kaggle\conv\yolov5\cute.mp4: 384x640 Done. (0.011s)
# ...
